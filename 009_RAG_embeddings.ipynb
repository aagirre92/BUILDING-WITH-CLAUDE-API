# %% [markdown]
# # Text Embeddings

# %%
# Install VoyageAI lib
# %pip install voyageai
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting voyageai
#   Downloading voyageai-0.3.7-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: aiohttp in c:\users\andoni_aguirre_arang\appdata\roaming\python\python312\site-packages (from voyageai) (3.12.7)
# Collecting aiolimiter (from voyageai)
#   Downloading aiolimiter-1.2.1-py3-none-any.whl.metadata (4.5 kB)
# Collecting ffmpeg-python (from voyageai)
#   Downloading ffmpeg_python-0.2.0-py3-none-any.whl.metadata (1.7 kB)
# Collecting langchain-text-splitters>=0.3.8 (from voyageai)
#   Downloading langchain_text_splitters-1.1.1-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: numpy in c:\users\andoni_aguirre_arang\appdata\roaming\python\python312\site-packages (from voyageai) (2.1.3)
# Requirement already satisfied: pillow in c:\users\andoni_aguirre_arang\appdata\roaming\python\python312\site-packages (from voyageai) (11.0.0)
# Requirement already satisfied: pydantic>=1.10.8 in c:\users\andoni_aguirre_arang\appdata\roaming\python\python312\site-packages (from voyageai) (2.10.6)
# Requirement already satisfied: requests in c:\programdata\miniconda3\lib\site-packages (from voyageai) (2.32.3)
# Requirement already satisfied: tenacity in c:\users\andoni_aguirre_arang\appdata\roaming\python\python312\site-packages (from voyageai) (9.0.0)
# Collecting tokenizers>=0.14.0 (from voyageai)
#   Downloading tokenizers-0.22.2-cp39-abi3-win_amd64.whl.metadata (7.4 kB)
# Collecting langchain-core<2.0.0,>=1.2.13 (from langchain-text-splitters>=0.3.8->voyageai)
#   Downloading langchain_core-1.2.30-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\andoni_aguirre_arang\appdata\roaming\python\python312\site-packages (from pydantic>=1.10.8->voyageai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\andoni_aguirre_arang\appdata\roaming\python\python312\site-packages (from pydantic>=1.10.8->voyageai) (2.27.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\andoni_aguirre_arang\appdata\roaming\python\python312\site-packages (from pydantic>=1.10.8->voyageai) (4.15.0)
# Collecting huggingface-hub<2.0,>=0.16.4 (from tokenizers>=0.14.0->voyageai)
#   Downloading huggingface_hub-1.11.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\andoni_aguirre_arang\appdata\roaming\python\python312\site-packages (from aiohttp->voyageai) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\andoni_aguirre_arang\appdata\roaming\python\python312\site-packages (from aiohttp->voyageai) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\andoni_aguirre_arang\appdata\roaming\python\python312\site-packages (from aiohttp->voyageai) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\andoni_aguirre_arang\appdata\roaming\python\python312\site-packages (from aiohttp->voyageai) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\andoni_aguirre_arang\appdata\roaming\python\python312\site-packages (from aiohttp->voyageai) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\andoni_aguirre_arang\appdata\roaming\python\python312\site-packages (from aiohttp->voyageai) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\andoni_aguirre_arang\appdata\roaming\python\python312\site-packages (from aiohttp->voyageai) (1.20.0)
# Collecting future (from ffmpeg-python->voyageai)
#   Downloading future-1.0.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\miniconda3\lib\site-packages (from requests->voyageai) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\miniconda3\lib\site-packages (from requests->voyageai) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\miniconda3\lib\site-packages (from requests->voyageai) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\miniconda3\lib\site-packages (from requests->voyageai) (2024.8.30)
# Collecting filelock>=3.10.0 (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.14.0->voyageai)
#   Downloading filelock-3.28.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting fsspec>=2023.5.0 (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.14.0->voyageai)
#   Downloading fsspec-2026.3.0-py3-none-any.whl.metadata (10 kB)
# Collecting hf-xet<2.0.0,>=1.4.3 (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.14.0->voyageai)
#   Downloading hf_xet-1.4.3-cp37-abi3-win_amd64.whl.metadata (4.9 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\programdata\miniconda3\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (0.27.0)
# Requirement already satisfied: packaging>=20.9 in c:\programdata\miniconda3\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\programdata\miniconda3\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (6.0.1)
# Requirement already satisfied: tqdm>=4.42.1 in c:\programdata\miniconda3\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (4.66.4)
# Collecting typer (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.14.0->voyageai)
#   Downloading typer-0.24.1-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\programdata\miniconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.13->langchain-text-splitters>=0.3.8->voyageai) (1.33)
# Collecting langsmith<1.0.0,>=0.3.45 (from langchain-core<2.0.0,>=1.2.13->langchain-text-splitters>=0.3.8->voyageai)
#   Downloading langsmith-0.7.32-py3-none-any.whl.metadata (15 kB)
# Collecting uuid-utils<1.0,>=0.12.0 (from langchain-core<2.0.0,>=1.2.13->langchain-text-splitters>=0.3.8->voyageai)
#   Downloading uuid_utils-0.14.1-cp39-abi3-win_amd64.whl.metadata (4.9 kB)
# Requirement already satisfied: anyio in c:\programdata\miniconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (4.2.0)
# Requirement already satisfied: httpcore==1.* in c:\programdata\miniconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (1.0.2)
# Requirement already satisfied: sniffio in c:\programdata\miniconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\programdata\miniconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\programdata\miniconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.13->langchain-text-splitters>=0.3.8->voyageai) (2.1)
# Collecting orjson>=3.9.14 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.13->langchain-text-splitters>=0.3.8->voyageai)
#   Downloading orjson-3.11.8-cp312-cp312-win_amd64.whl.metadata (43 kB)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\andoni_aguirre_arang\appdata\roaming\python\python312\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.13->langchain-text-splitters>=0.3.8->voyageai) (1.0.0)
# Collecting xxhash>=3.0.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.13->langchain-text-splitters>=0.3.8->voyageai)
#   Downloading xxhash-3.6.0-cp312-cp312-win_amd64.whl.metadata (13 kB)
# Collecting zstandard>=0.23.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.13->langchain-text-splitters>=0.3.8->voyageai)
#   Downloading zstandard-0.25.0-cp312-cp312-win_amd64.whl.metadata (3.3 kB)
# Requirement already satisfied: colorama in c:\programdata\miniconda3\lib\site-packages (from tqdm>=4.42.1->huggingface-hub<2.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (0.4.6)
# Collecting click>=8.2.1 (from typer->huggingface-hub<2.0,>=0.16.4->tokenizers>=0.14.0->voyageai)
#   Downloading click-8.3.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting shellingham>=1.3.0 (from typer->huggingface-hub<2.0,>=0.16.4->tokenizers>=0.14.0->voyageai)
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting rich>=12.3.0 (from typer->huggingface-hub<2.0,>=0.16.4->tokenizers>=0.14.0->voyageai)
#   Downloading rich-15.0.0-py3-none-any.whl.metadata (18 kB)
# Collecting annotated-doc>=0.0.2 (from typer->huggingface-hub<2.0,>=0.16.4->tokenizers>=0.14.0->voyageai)
#   Using cached annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Collecting markdown-it-py>=2.2.0 (from rich>=12.3.0->typer->huggingface-hub<2.0,>=0.16.4->tokenizers>=0.14.0->voyageai)
#   Downloading markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\programdata\miniconda3\lib\site-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (2.15.1)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub<2.0,>=0.16.4->tokenizers>=0.14.0->voyageai)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading voyageai-0.3.7-py3-none-any.whl (34 kB)
# Downloading langchain_text_splitters-1.1.1-py3-none-any.whl (35 kB)
# Downloading tokenizers-0.22.2-cp39-abi3-win_amd64.whl (2.7 MB)
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/2.7 MB ? eta -:--:--
#    ------------------- -------------------- 1.3/2.7 MB 4.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 2.4/2.7 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.7/2.7 MB 3.7 MB/s eta 0:00:00
# Downloading aiolimiter-1.2.1-py3-none-any.whl (6.7 kB)
# Downloading ffmpeg_python-0.2.0-py3-none-any.whl (25 kB)
# Downloading huggingface_hub-1.11.0-py3-none-any.whl (645 kB)
#    ---------------------------------------- 0.0/645.5 kB ? eta -:--:--
#    ---------------------------------------- 645.5/645.5 kB 4.1 MB/s eta 0:00:00
# Downloading langchain_core-1.2.30-py3-none-any.whl (513 kB)
# Downloading future-1.0.0-py3-none-any.whl (491 kB)
# Downloading filelock-3.28.0-py3-none-any.whl (39 kB)
# Downloading fsspec-2026.3.0-py3-none-any.whl (202 kB)
# Downloading hf_xet-1.4.3-cp37-abi3-win_amd64.whl (3.7 MB)
#    ---------------------------------------- 0.0/3.7 MB ? eta -:--:--
#    -------------- ------------------------- 1.3/3.7 MB 6.1 MB/s eta 0:00:01
#    ---------------------------- ----------- 2.6/3.7 MB 6.0 MB/s eta 0:00:01
#    ---------------------------------------  3.7/3.7 MB 5.6 MB/s eta 0:00:01
#    ---------------------------------------- 3.7/3.7 MB 4.5 MB/s eta 0:00:00
# Downloading langsmith-0.7.32-py3-none-any.whl (378 kB)
# Downloading uuid_utils-0.14.1-cp39-abi3-win_amd64.whl (187 kB)
# Downloading typer-0.24.1-py3-none-any.whl (56 kB)
# Using cached annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Downloading click-8.3.2-py3-none-any.whl (108 kB)
# Downloading orjson-3.11.8-cp312-cp312-win_amd64.whl (127 kB)
# Downloading rich-15.0.0-py3-none-any.whl (310 kB)
# Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading xxhash-3.6.0-cp312-cp312-win_amd64.whl (31 kB)
# Downloading zstandard-0.25.0-cp312-cp312-win_amd64.whl (506 kB)
# Downloading markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: zstandard, xxhash, uuid-utils, shellingham, orjson, mdurl, hf-xet, future, fsspec, filelock, click, annotated-doc, aiolimiter, markdown-it-py, ffmpeg-python, rich, langsmith, typer, langchain-core, langchain-text-splitters, huggingface-hub, tokenizers, voyageai
# Successfully installed aiolimiter-1.2.1 annotated-doc-0.0.4 click-8.3.2 ffmpeg-python-0.2.0 filelock-3.28.0 fsspec-2026.3.0 future-1.0.0 hf-xet-1.4.3 huggingface-hub-1.11.0 langchain-core-1.2.30 langchain-text-splitters-1.1.1 langsmith-0.7.32 markdown-it-py-4.0.0 mdurl-0.1.2 orjson-3.11.8 rich-15.0.0 shellingham-1.5.4 tokenizers-0.22.2 typer-0.24.1 uuid-utils-0.14.1 voyageai-0.3.7 xxhash-3.6.0 zstandard-0.25.0
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts futurize.exe and pasteurize.exe are installed in 'C:\Users\Andoni_Aguirre_Arang\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script markdown-it.exe is installed in 'C:\Users\Andoni_Aguirre_Arang\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script typer.exe is installed in 'C:\Users\Andoni_Aguirre_Arang\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts hf.exe, huggingface-cli.exe and tiny-agents.exe are installed in 'C:\Users\Andoni_Aguirre_Arang\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
# Client Setup
from dotenv import load_dotenv
import voyageai

load_dotenv()

client = voyageai.Client()

# %%
# Chunk by section
import re


def chunk_by_section(document_text):
    pattern = r"\n## "
    return re.split(pattern, document_text)

# %%
# Embedding Generation
def generate_embedding(text, model="voyage-3-large", input_type="query"):
    result = client.embed([text], model=model, input_type=input_type)

    return result.embeddings[0]

# %%
with open("./report.md", "r") as f:
    text = f.read()

chunks = chunk_by_section(text) # Get the first chunk


# Pass first chunk to embedding
embeddings = generate_embedding(chunks[0])

# %%
len(embeddings)
# Out:
# 1024

# %%
embeddings[0:20]
# Out:
# [-0.05453480780124664,
#  0.01431055087596178,
#  -0.016921261325478554,
#  0.0005922440905123949,
#  0.02136913500726223,
#  0.037903621792793274,
#  -0.047186143696308136,
#  0.0024173229467123747,
#  0.0025865354109555483,
#  -0.01798488199710846,
#  0.014020473696291447,
#  0.048926617950201035,
#  -0.00918582733720541,
#  -0.0037710238248109818,
#  -0.013730393722653389,
#  0.007010236848145723,
#  0.03326236084103584,
#  0.08857070654630661,
#  -0.04737953096628189,
#  -0.010201102122664452]
